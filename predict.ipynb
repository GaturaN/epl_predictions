# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2023-08-11  20:00  Premier League  Matchweek 1  Fri  Away      W  3.0  0.0
# 3  2023-08-19  20:00  Premier League  Matchweek 2  Sat  Home      W  1.0  0.0
# 4  2023-08-27  14:00  Premier League  Matchweek 3  Sun  Away      W  2.0  1.0
# 5  2023-09-02  15:00  Premier League  Matchweek 4  Sat  Home      W  5.0  1.0
# 6  2023-09-16  15:00  Premier League  Matchweek 5  Sat  Away      W  3.0  1.0
#
#         opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1        Burnley  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0.0   0.0
# 3  Newcastle Utd  ...  Match Report    NaN  14.0   4.0  17.9  0.0  0.0   0.0
# 4  Sheffield Utd  ...  Match Report    NaN  29.0   9.0  17.3  2.0  0.0   1.0
# 5         Fulham  ...  Match Report    NaN   6.0   4.0  14.8  0.0  1.0   1.0
# 6       West Ham  ...  Match Report    NaN  29.0  13.0  16.4  1.0  0.0   0.0
#
#    season            team
# ...

# %%
matches.shape
# Out:
# (2620, 27)

# %%
# Converting the 'date' column to datetime format
matches['date'] = pd.to_datetime(matches['date'])

# %%
# Picking data from only two seasons i.e 2021/2022 & 2022/2023

end_date = pd.to_datetime('2023-09-29') #end of 2022 season
start_date = pd.to_datetime('2022-08-04')  #beginning of 2021 season


matches = matches[(matches['date'] < end_date) & (matches['date'] > start_date)]

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W  3.0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W  1.0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2.0
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5.0
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 41 2023-05-14  16:30  Premier League  Matchweek 36  Sun  Away      W  3.0
# 42 2023-05-18  19:30  Premier League  Matchweek 25  Thu  Away      L  1.0
# 43 2023-05-21  14:00  Premier League  Matchweek 37  Sun  Home      W  3.0
# 44 2023-05-24  20:00  Premier League  Matchweek 32  Wed  Home      D  1.0
# 45 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L  1.0
#
#      ga         opponent  ...  match report  notes    sh   sot  dist   fk  \
# ...

# %%
print(matches['date'].max())
print(matches['date'].min())
# Out:
# 2023-09-24 00:00:00
# 2022-08-05 00:00:00

# %%
matches.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team'],
#       dtype='object')

# %%
matches["team"].value_counts()
# Out:
# Arsenal                   44
# ManchesterUnited          44
# ManchesterCity            44
# BrightonandHoveAlbion     44
# Liverpool                 44
# NewcastleUnited           44
# Fulham                     6
# Chelsea                    6
# WestHamUnited              6
# AstonVilla                 6
# Brentford                  6
# CrystalPalace              6
# WolverhamptonWanderers     6
# NottinghamForest           6
# TottenhamHotspur           6
# Everton                    6
# Bournemouth                6
# Burnley                    5
# LutonTown                  5
# Name: team, dtype: int64
